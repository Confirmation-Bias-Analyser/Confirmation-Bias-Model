# %%
import pandas as pd
from anytree import Node, RenderTree, search
import datetime
import time
from functions import *

# %%
df = pd.read_csv('Datasets/sample_tweet_conversation.csv', dtype=object)
df['id'] = df['id'].astype(str)
df['reply_to'] = df['reply_to'].astype(str)
df
# Out:
#                      id                 timestamp             reply_to  \
# 0   1435908999572955139  2022-02-10T22:30:38.000Z             87818409
# 1   1394744372097339393  2022-02-10T19:45:16.000Z             87818409
# 2   1267097982446469123  2022-02-10T18:49:35.000Z             87818409
# 3    884725084371521536  2022-02-10T15:17:25.000Z             87818409
# 4   1001839970221469696  2022-02-10T14:25:51.000Z             87818409
# 5    740644181102714880  2022-02-10T13:26:59.000Z             87818409
# 6            2385178980  2022-02-10T12:43:03.000Z             87818409
# 7   1474601677500018694  2022-02-10T07:13:06.000Z             87818409
# 8   1482195169751580672  2022-02-09T20:24:30.000Z  1482195169751580672
# 9   1482195169751580672  2022-02-09T20:24:14.000Z  1482195169751580672
# 10  1482195169751580672  2022-02-09T20:23:52.000Z             87818409
# 11  1482195169751580672  2022-02-09T20:23:30.000Z             87818409
# 12  1371691259019071489  2022-02-09T16:47:16.000Z             87818409
# 13           2922675910  2022-02-09T16:17:57.000Z             87818409
# 14  1456904144472588292  2022-02-09T12:02:22.000Z             87818409
# 15  1456904144472588292  2022-02-09T11:45:39.000Z             87818409
# 16  1469206590767210497  2022-02-08T15:13:24.000Z             87818409
# 17  1474601677500018694  2022-02-08T14:30:56.000Z             87818409
# 18           3190398697  2022-02-08T11:16:36.000Z             87818409
# 19  1001839970221469696  2022-02-07T19:30:08.000Z             87818409
# 20  1001839970221469696  2022-02-07T19:11:34.000Z             87818409
# 21  1001839970221469696  2022-02-07T18:46:19.000Z             87818409
# 22           1937076228  2022-02-07T18:43:16.000Z             87818409
# 23  1467927466920628229  2022-02-07T18:38:33.000Z             87818409
# 24  1469206590767210497  2022-02-07T16:44:49.000Z             87818409
# 25  1421960878375714820  2022-02-07T15:02:50.000Z             87818409
# 26  1478456296819068941  2022-02-07T13:46:27.000Z             87818409
# 27  1225544341789270017  2022-02-07T11:20:59.000Z             87818409
# 28   847475426838446084  2022-02-07T00:21:10.000Z             87818409
# 29  1001839970221469696  2022-02-06T21:47:29.000Z             87818409
# 30  1461132681207443458  2022-02-06T18:41:27.000Z             87818409
# 31  1465599571854299142  2022-02-06T17:35:14.000Z             87818409
# 32  1319461064111697920  2022-02-06T13:52:32.000Z             87818409
# 33  1001839970221469696  2022-02-06T01:22:46.000Z             87818409
# 34  1001839970221469696  2022-02-05T20:54:50.000Z             87818409
# 35  1470337517341880324  2022-02-05T16:37:36.000Z             87818409
# 36  1105682057097871360  2022-02-05T16:02:00.000Z             87818409
# 37  1001839970221469696  2022-02-05T12:59:43.000Z             87818409
# 38  1001839970221469696  2022-02-05T02:47:04.000Z             87818409
# 39  1001839970221469696  2022-02-05T01:20:02.000Z             87818409
# 40             30995239  2022-02-04T22:36:21.000Z             87818409
# 41  1330122460193239040  2022-02-04T17:30:42.000Z             87818409
# 42   970914910656958464  2022-02-04T16:43:33.000Z             87818409
# 43  1001839970221469696  2022-02-04T15:40:36.000Z             87818409
# 44  1001839970221469696  2022-02-04T15:35:01.000Z             87818409
# 45  1489307931308965890  2022-02-04T02:00:41.000Z             87818409
# 46  1001839970221469696  2022-02-04T01:21:33.000Z             87818409
# 47  1001839970221469696  2022-02-04T00:53:55.000Z             87818409
#
#                                               comment    new_id  \
# 0   @guardian You say your independent with ‘value...  KbLfC5GE
# 1   @guardian Times certainly do change, any thoug...  UetMh5h7
# 2   @guardian sick English fascist nation, are you...  cDYrS6fv
# 3   @guardian Values like client journalism and ve...  8jrlTr58
# 4                   @guardian https://t.co/q58wQRExSe  mMopkhLx
# 5   @guardian I was sexually assaulted by consulta...  0d3CLrMh
# 6   @guardian I used to love the Guardian. I was v...  Ce8yE2A9
# 7   @guardian Hi guys, I would recommend a great S...  RK5nY7re
# 8                                    @guardian ☮️🌎💙🧠🐺  QdkdOpFX
# 9                                     @guardian ⛳️🙉🙊🙈  xbNuCzmu
# 10       @guardian The Good Word from the Good Book 📖  JjksEDaW
# 11           @guardian The Code / The Oath / OUR WORD  QaSEObL8
# 12                  @guardian https://t.co/uL5LVNsGeg  4cFbuF1l
# 13                  @guardian https://t.co/9ky1M24T2P  zzeJmljd
# 14  @guardian Hi guys, I would recommend a great S...  kqU0Ebi8
# 15  @guardian Hi guys, I would recommend a great S...  UY8Ij5iH
# 16  @guardian people be careful on this famous dj ...  kfhyogUh
# 17  @guardian Hi guys, I would recommend a great S...  RyaKF4Gn
# 18  @guardian False 'Elders' signing for ALL of us...  GOigdETQ
# 19                  @guardian https://t.co/J2yD7wez3O  dJHymWM7
# 20                  @guardian https://t.co/5zUPcKOCKa  ZkVN6BIu
# 21                  @guardian https://t.co/7wBhtm5VBA  zJNir35n
# 22  @guardian Do I Get Paid $100 for Each Affiliat...  02isDEo1
# 23  @guardian I implore that any of you to help me...  kukRjMOa
# 24  @guardian this dj KYGO liked to write  to orph...  AvaS37Ds
# 25  @guardian The Guardian won't talk about what's...  3dpJ3uas
# 26  @guardian @guardian values don't change @KathV...  EPdgZITP
# 27  @guardian WORLD WAR 1  AIRSOFT CHAMPIONSHIP \n...  kNEg3YTx
# 28  @guardian Did The Guardian allow Joseph O’Conn...  2Mbw44AG
# 29                  @guardian https://t.co/jxzs8dDctT  G6Zj59Dl
# 30  @guardian You a-holes are all opinion based. Y...  SHDQzRIG
# 31                  @guardian https://t.co/j92fkgUTvP  q3AFnRBP
# 32                  @guardian https://t.co/Uh1D3GqFwj  J6rAVExb
# 33                  @guardian https://t.co/oSkHlKSEbi  DfgUdqrF
# 34                  @guardian https://t.co/dEmWJjaV5l  kWe4pQ8S
# 35  @guardian https://t.co/sc65nJCyva  Nazifascist...  H6B34456
# 36  @guardian The famillies of the opinion prisonn...  65CGfjzH
# 37                  @guardian https://t.co/ZYneU73zL1  398uvFBo
# 38                  @guardian https://t.co/0lzUuJjPxo  eX6jeoa3
# 39                  @guardian https://t.co/V9bnRfCFwV  bWxXh0nO
# 40  @guardian The guardians continual decline cont...  9wx6oWqA
# 41  @guardian Thanks Boris, It it’s been fun - apa...  PgQhu3bv
# 42           @guardian #SaveKashmir\n#IndianTerrorism  PHTGJKrW
# 43                  @guardian https://t.co/n5zAVdewW9  UIVVOfAB
# 44                  @guardian https://t.co/QXgZhJt9GN  RajORwY9
# 45  @guardian Hello, I am David a professional dig...  DwnQcrEO
# 46                  @guardian https://t.co/p3vAzYFBh0  yQER9xO1
# 47                  @guardian https://t.co/q5StjpDjtR  xbrLlL0I
#
#                                                   url  \
# 0                                                 NaN
# 1                            https://t.co/dtufbIGrv5;
# 2                                                 NaN
# 3   https://twitter.com/NicCicutti/status/14917010...
# 4   https://twitter.com/Linn45350887/status/149177...
# 5                                                 NaN
# 6                                                 NaN
# 7   https://t.co/ZuAhguw1nr;https://twitter.com/ri...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  https://twitter.com/ellmemore/status/149145365...
# 13                           https://t.co/9ky1M24T2P;
# 14  https://t.co/7y9WA0Viv1;https://twitter.com/ar...
# 15  https://t.co/f1A2AZK9wJ;https://twitter.com/ar...
# 16                                                NaN
# 17  https://t.co/leCFTqs1qT;https://twitter.com/ri...
# 18  https://t.me/grahamhood/103?fbclid=IwAR1_Tqbt8...
# 19  https://twitter.com/Linn45350887/status/149076...
# 20  https://twitter.com/Linn45350887/status/149076...
# 21  https://twitter.com/Linn45350887/status/149075...
# 22                           https://t.co/zJKj3XrO3G;
# 23           https://t.co/F4CVyJUoam.Hope@gmail.com.;
# 24                                                NaN
# 25  https://twitter.com/PauloHo28849071/status/149...
# 26  https://twitter.com/RivkahBrown/status/1489649...
# 27  https://twitter.com/zeiraw05161987/status/1490...
# 28                                                NaN
# 29  https://twitter.com/Linn45350887/status/149016...
# 30                                                NaN
# 31  https://www.hepsiburadan.net/2021/09/galaxy-ta...
# 32  https://twitter.com/Walcandy1/status/149032251...
# 33  https://twitter.com/Linn45350887/status/149013...
# 34  https://twitter.com/Linn45350887/status/149006...
# 35  https://www.radarfeminista.com.br/post/instrum...
# 36  https://twitter.com/bendjimli18/status/1489992...
# 37  https://twitter.com/Linn45350887/status/148940...
# 38  https://twitter.com/Linn45350887/status/148979...
# 39  https://twitter.com/Linn45350887/status/148977...
# 40  https://twitter.com/aaronbastani/status/148965...
# 41  https://twitter.com/ambleforth/status/14896526...
# 42                                                NaN
# 43  https://twitter.com/Linn45350887/status/148961...
# 44  https://twitter.com/Linn45350887/status/148961...
# 45                           https://t.co/zZhSRQLTG0;
# 46  https://twitter.com/Linn45350887/status/148940...
# 47  https://twitter.com/Linn45350887/status/148940...
#
#                        link_title parent_id
# 0                             NaN  24JkpHAK
# 1                        ['t.co']  24JkpHAK
# 2                             NaN  24JkpHAK
# 3                 ['twitter.com']  24JkpHAK
# 4                 ['twitter.com']  24JkpHAK
# 5                             NaN  24JkpHAK
# 6                             NaN  24JkpHAK
# 7         ['t.co', 'twitter.com']  24JkpHAK
# 8                             NaN  QdkdOpFX
# 9                             NaN  QdkdOpFX
# 10                            NaN  24JkpHAK
# 11                            NaN  24JkpHAK
# 12                ['twitter.com']  24JkpHAK
# 13                       ['t.co']  24JkpHAK
# 14        ['t.co', 'twitter.com']  24JkpHAK
# 15        ['t.co', 'twitter.com']  24JkpHAK
# 16                            NaN  24JkpHAK
# 17        ['t.co', 'twitter.com']  24JkpHAK
# 18                       ['t.me']  24JkpHAK
# 19                ['twitter.com']  24JkpHAK
# 20                ['twitter.com']  24JkpHAK
# 21                ['twitter.com']  24JkpHAK
# 22                       ['t.co']  24JkpHAK
# 23                       ['t.co']  24JkpHAK
# 24                            NaN  24JkpHAK
# 25                ['twitter.com']  24JkpHAK
# 26                ['twitter.com']  24JkpHAK
# 27                ['twitter.com']  24JkpHAK
# 28                            NaN  24JkpHAK
# 29                ['twitter.com']  24JkpHAK
# 30                            NaN  24JkpHAK
# 31       ['www.hepsiburadan.net']  24JkpHAK
# 32                ['twitter.com']  24JkpHAK
# 33                ['twitter.com']  24JkpHAK
# 34                ['twitter.com']  24JkpHAK
# 35  ['www.radarfeminista.com.br']  24JkpHAK
# 36                ['twitter.com']  24JkpHAK
# 37                ['twitter.com']  24JkpHAK
# 38                ['twitter.com']  24JkpHAK
# 39                ['twitter.com']  24JkpHAK
# 40                ['twitter.com']  24JkpHAK
# 41                ['twitter.com']  24JkpHAK
# 42                            NaN  24JkpHAK
# 43                ['twitter.com']  24JkpHAK
# 44                ['twitter.com']  24JkpHAK
# 45                       ['t.co']  24JkpHAK
# 46                ['twitter.com']  24JkpHAK
# 47                ['twitter.com']  24JkpHAK

# %% [markdown]
# ## Tree of Comments

# %%
# parent = '18831926' # Actual ST ID
parent = '24JkpHAK'
root = Node(parent)

input_list = [] 
item_count = df['parent_id'].value_counts().to_dict()

for i in range(len(df['new_id'].tolist())):
    if df['new_id'].loc[i] != df['parent_id'].loc[i]:
        input_list.append((df['new_id'].loc[i], df['parent_id'].loc[i]))

output_dict = make_map(input_list)
createTree(output_dict[parent], root)

# %%
for pre, fill, node in RenderTree(root):
    print("%s%s" % (pre, node.name))
# Out:
# 24JkpHAK
# ├── KbLfC5GE
# ├── UetMh5h7
# ├── cDYrS6fv
# ├── 8jrlTr58
# ├── mMopkhLx
# ├── 0d3CLrMh
# ├── Ce8yE2A9
# ├── RK5nY7re
# ├── JjksEDaW
# ├── QaSEObL8
# ├── 4cFbuF1l
# ├── zzeJmljd
# ├── kqU0Ebi8
# ├── UY8Ij5iH
# ├── kfhyogUh
# ├── RyaKF4Gn
# ├── GOigdETQ
# ├── dJHymWM7
# ├── ZkVN6BIu
# ├── zJNir35n
# ├── 02isDEo1
# ├── kukRjMOa
# ├── AvaS37Ds
# ├── 3dpJ3uas
# ├── EPdgZITP
# ├── kNEg3YTx
# ├── 2Mbw44AG
# ├── G6Zj59Dl
# ├── SHDQzRIG
# ├── q3AFnRBP
# ├── J6rAVExb
# ├── DfgUdqrF
# ├── kWe4pQ8S
# ├── H6B34456
# ├── 65CGfjzH
# ├── 398uvFBo
# ├── eX6jeoa3
# ├── bWxXh0nO
# ├── 9wx6oWqA
# ├── PgQhu3bv
# ├── PHTGJKrW
# ├── UIVVOfAB
# ├── RajORwY9
# ├── DwnQcrEO
# ├── yQER9xO1
# └── xbrLlL0I

# %%
# conversation = traceConversation(df, root, '')
# conversation

# %%
# count = 0
# previous_scores = []

# for i in conversation.iloc():
#     if count != 0:
#         print(i['comment'], i['sentiment'])
#         print('Bias Score:', confirmationBiasScore(previous_scores, i['sentiment']))
#         print()
        
#     previous_scores.append(i['sentiment'])
    
#     count += 1

# %%
# def confirmationBiasScore(scores, current_score, threshold = 0.5):
#     positive_evidence = 0
#     negative_evidence = 0
    
#     neg_evidence_agree = 0
#     neg_evidence_disagree = 0
#     pos_evidence_agree = 0
#     pos_evidence_disagree = 0
    
#     for i in range(len(scores)):
#         if scores[i] < threshold:
#             negative_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] >= threshold:
#                 neg_evidence_disagree += 1
#             else:
#                 neg_evidence_agree += 1
#         else:
#             positive_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] < threshold:
#                 pos_evidence_disagree += 1
#             else:
#                 pos_evidence_agree += 1
    
#     try: H1 = pos_evidence_agree / (pos_evidence_agree + pos_evidence_disagree)
#     except: H1 = 0
        
#     try: H2 = neg_evidence_agree / (neg_evidence_agree + neg_evidence_disagree)
#     except: H2 = 0
            
#     # Assume D1 is positive evidence
#     D1 = positive_evidence / (positive_evidence + negative_evidence)
#     D2 = negative_evidence / (positive_evidence + negative_evidence)
    
#     try:
#         prob_D1_H1 = (D1 * H1) / ((D1 * H1) + (D2 * H1))
#     except:
#         prob_D1_H1 = 0
        
#     try:
#         prob_D1_H2 = (D1 * H2) / ((D1 * H2) + (D2 * H2))
#     except:
#         prob_D1_H2 = 0
    
#     return prob_D1_H1, prob_D1_H2
