# %%
import pandas as pd
from anytree import Node, RenderTree, search
import datetime
import time
from functions import *

# %%
df = pd.read_csv('Datasets/ST_twitter_data.csv', dtype=object)
df['id'] = df['id'].astype(str)
df['reply_to'] = df['reply_to'].astype(str)
df
# Out:
#                     id                 timestamp   reply_to  \
# 0            155512494  2022-02-12T10:37:33.000Z   37874853
# 1  1250959902299656192  2022-02-12T10:37:12.000Z   37874853
# 2            249757744  2022-02-12T09:59:00.000Z  297266496
# 3            297266496  2022-02-12T09:48:54.000Z   37874853
# 4            567250256  2022-02-12T09:44:18.000Z   37874853
# 5            197358208  2022-02-12T09:42:25.000Z  242694418
# 6  1422075857863020547  2022-02-12T09:40:02.000Z   37874853
# 7  1324691961182212096  2022-02-12T09:38:33.000Z  242694418
# 8            242694418  2022-02-12T09:30:00.000Z   37874853
#
#                                              comment  \
# 0                               @straits_times okay.
# 1  @straits_times Any folks can see from UK, Isra...
# 2  @jsz2017 @straits_times Are you seriously that...
# 3  @straits_times if he said this before MOH star...
# 4  @straits_times If one looks to the data of oth...
# 5  @kirschacay @straits_times Unmask and go aroun...
# 6  @straits_times i missed the part where thats m...
# 7         @kirschacay @straits_times Substantiate!!!
# 8                           @straits_times Fake news
#
#                                                  url       link_title
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  https://twitter.com/lukewearechange/status/147...  ['twitter.com']
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6                                                NaN              NaN
# 7                                                NaN              NaN
# 8                                                NaN              NaN

# %% [markdown]
# ## Tree of Comments

# %%
parent = '37874853'
root = Node(parent)

input_list = [] 
item_count = df['reply_to'].value_counts().to_dict()

for i in range(len(df['id'].tolist())):
    if df['id'].loc[i] != df['reply_to'].loc[i]:
        input_list.append((df['id'].loc[i], df['reply_to'].loc[i]))

output_dict = make_map(input_list)
createTree(output_dict[parent], root)

# %%
for pre, fill, node in RenderTree(root):
    print("%s%s" % (pre, node.name))
# Out:
# 37874853
# ├── 155512494
# ├── 1250959902299656192
# ├── 297266496
# │   └── 249757744
# ├── 567250256
# ├── 1422075857863020547
# └── 242694418
#     ├── 197358208
#     └── 1324691961182212096

# %%
# conversation = traceConversation(df, root, '')
# conversation

# %%
# count = 0
# previous_scores = []

# for i in conversation.iloc():
#     if count != 0:
#         print(i['comment'], i['sentiment'])
#         print('Bias Score:', confirmationBiasScore(previous_scores, i['sentiment']))
#         print()
        
#     previous_scores.append(i['sentiment'])
    
#     count += 1

# %%
# def confirmationBiasScore(scores, current_score, threshold = 0.5):
#     positive_evidence = 0
#     negative_evidence = 0
    
#     neg_evidence_agree = 0
#     neg_evidence_disagree = 0
#     pos_evidence_agree = 0
#     pos_evidence_disagree = 0
    
#     for i in range(len(scores)):
#         if scores[i] < threshold:
#             negative_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] >= threshold:
#                 neg_evidence_disagree += 1
#             else:
#                 neg_evidence_agree += 1
#         else:
#             positive_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] < threshold:
#                 pos_evidence_disagree += 1
#             else:
#                 pos_evidence_agree += 1
    
#     try: H1 = pos_evidence_agree / (pos_evidence_agree + pos_evidence_disagree)
#     except: H1 = 0
        
#     try: H2 = neg_evidence_agree / (neg_evidence_agree + neg_evidence_disagree)
#     except: H2 = 0
            
#     # Assume D1 is positive evidence
#     D1 = positive_evidence / (positive_evidence + negative_evidence)
#     D2 = negative_evidence / (positive_evidence + negative_evidence)
    
#     try:
#         prob_D1_H1 = (D1 * H1) / ((D1 * H1) + (D2 * H1))
#     except:
#         prob_D1_H1 = 0
        
#     try:
#         prob_D1_H2 = (D1 * H2) / ((D1 * H2) + (D2 * H2))
#     except:
#         prob_D1_H2 = 0
    
#     return prob_D1_H1, prob_D1_H2
