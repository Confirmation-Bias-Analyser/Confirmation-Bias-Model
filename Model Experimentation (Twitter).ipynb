# %%
import pandas as pd
from anytree import Node, RenderTree, search
import datetime
import time
from functions import *

# %%
# df = pd.read_csv('Datasets/ST_twitter_data.csv', dtype=object)
df = pd.read_csv('Datasets/CNA_twitter_data.csv', dtype=object)
df['id'] = df['id'].astype(str)
df['reply_to'] = df['reply_to'].astype(str)
df
# Out:
#                      id                 timestamp             reply_to  \
# 0    772905235245326337  2022-03-02T07:08:56.000Z             87818409
# 1             183334937  2022-03-01T21:28:54.000Z            441670370
# 2             441670370  2022-03-01T19:56:23.000Z   984163135715139584
# 3             441670370  2022-03-01T19:52:14.000Z             57862328
# 4             441670370  2022-03-01T19:47:13.000Z            183334937
# 5             704524850  2022-03-01T14:49:13.000Z             87818409
# 6   1164205166486327302  2022-03-01T12:08:22.000Z             87818409
# 7            1923178369  2022-03-01T10:33:45.000Z             87818409
# 8   1458581361502076928  2022-03-01T09:25:34.000Z             87818409
# 9             705066850  2022-03-01T09:20:55.000Z             87818409
# 10   984163135715139584  2022-03-01T08:58:01.000Z             87818409
# 11   984163135715139584  2022-03-01T08:55:41.000Z  1493604703623847938
# 12   984163135715139584  2022-03-01T08:51:30.000Z             87818409
# 13   775390461414477824  2022-03-01T08:21:07.000Z             87818409
# 14           4761396386  2022-03-01T08:12:36.000Z             87818409
# 15            183334937  2022-03-01T08:07:21.000Z  1493604703623847938
# 16           3301667555  2022-03-01T07:49:57.000Z             87818409
# 17             57124092  2022-03-01T07:43:01.000Z             87818409
# 18             47247335  2022-03-01T07:38:26.000Z             87818409
# 19             82196380  2022-03-01T07:34:55.000Z             87818409
# 20           2215977381  2022-03-01T07:34:45.000Z            908629578
# 21            908629578  2022-03-01T07:33:54.000Z           2215977381
# 22             57862328  2022-03-01T07:32:12.000Z             87818409
# 23            596695193  2022-03-01T07:30:18.000Z             87818409
# 24           2215977381  2022-03-01T07:28:02.000Z             87818409
# 25            126413854  2022-03-01T07:23:19.000Z             87818409
# 26  1493604703623847938  2022-03-01T07:22:45.000Z             87818409
# 27           2747163550  2022-03-01T07:22:33.000Z             87818409
# 28            168161616  2022-03-01T07:21:44.000Z             87818409
# 29  1424376789636423688  2022-03-01T07:20:14.000Z             87818409
# 30   962447636358889473  2022-03-01T07:17:38.000Z             87818409
# 31            207879183  2022-03-01T07:17:35.000Z             87818409
# 32           2211342025  2022-03-01T07:16:25.000Z             87818409
# 33             27470516  2022-03-01T07:16:13.000Z             87818409
# 34  1393788382619209729  2022-03-01T07:14:38.000Z             87818409
# 35  1374047463041073153  2022-03-01T07:14:28.000Z             87818409
# 36   884827243553411072  2022-03-01T07:14:18.000Z             87818409
#
#                                               comment new_id reply_to_id  \
# 0         @guardian The fairness of the free world 🤢🤮  10000    87818409
# 1   @HohoChan657 @DanielArcher007 @guardian Really...  10001       10002
# 2   @Ted_Wilson_efg @guardian Sanction AmeriKKKa f...  10002       10010
# 3   @brush_tool @guardian A new word for you to le...  10003       10022
# 4   @andalg1 @DanielArcher007 @guardian Cancel all...  10004       10001
# 5                                      @guardian Good  10005    87818409
# 6   @guardian This xenophobia towards Russian civi...  10006    87818409
# 7   @guardian Not everywhere. The Last Night of th...  10007    87818409
# 8   @guardian Ok that s just idiotic. What s next,...  10008    87818409
# 9         @guardian But Israel is still in Eurovision  10009    87818409
# 10  @guardian Are the Guardian's arts editors seri...  10010    87818409
# 11  @DanielArcher007 @guardian Good question Danie...  10011       10026
# 12  @guardian Hundreds of thousands of Russians wi...  10012    87818409
# 13  @guardian Units of Belarusian special operatio...  10013    87818409
# 14                                  @guardian 这是世界的损失  10014    87818409
# 15  @DanielArcher007 @guardian Because they need t...  10015       10026
# 16     @guardian 😂😂you’ve made your bed now lay on it  10016    87818409
# 17                    @guardian Cancel war and peace!  10017    87818409
# 18  @guardian People have lost their collective mi...  10018    87818409
# 19  @guardian Good. Russia must feel pain in every...  10019    87818409
# 20  @AndrewFellow5 @guardian Nobody claims otherwise.  10020       10021
# 21  @MraPapadopoulou @guardian Even sadder day for...  10021       10020
# 22  @guardian Russian art is heavily based on othe...  10022    87818409
# 23  @guardian Why have you made the choice by me? ...  10023    87818409
# 24                    @guardian Sad days for the arts  10024    87818409
# 25                        @guardian #StandWithUkraine  10025    87818409
# 26  @guardian Why Russian citizens have to pay for...  10026    87818409
# 27  @guardian Start online Part-Time Job and Earn ...  10027    87818409
# 28  @guardian You call it industrial revolution,\n...  10028    87818409
# 29  @guardian Putin is leading his country to a to...  10029    87818409
# 30                                     @guardian Good  10030    87818409
# 31                            @guardian 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣  10031    87818409
# 32  @guardian I never saw this happen when ME coun...  10032    87818409
# 33                                  @guardian @noctav  10033    87818409
# 34                  @guardian https://t.co/m6aRaJbcGg  10034    87818409
# 35    @guardian A Nazi practice concerning Jewish art  10035    87818409
# 36  @guardian If phone is service down, you can us...  10036    87818409
#
#                                                   url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                            https://t.co/gYOHPuG0HU;
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                https://payoutto.com/?userid=59544;
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  https://twitter.com/m7mdkurd/status/1498334662...
# 35                                                NaN
# 36  https://apps.apple.com/us/app/bost-app/id14785...
#
#                                            link_title
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                            ['t.co']
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                   ['payoutto.com']
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                    ['twitter.com']
# 35                                                NaN
# 36  ['apps.apple.com', 'play.google.com', 'twitter...

# %% [markdown]
# ## Tree of Comments

# %%
# parent = '37874853'
parent = '87818409'
root = Node(parent)

input_list = [] 
item_count = df['reply_to_id'].value_counts().to_dict()

for i in range(len(df['new_id'].tolist())):
    if df['new_id'].loc[i] != df['reply_to_id'].loc[i]:
        input_list.append((df['new_id'].loc[i], df['reply_to_id'].loc[i]))

# %%
output_dict = make_map(input_list)
createTree(output_dict[parent], root)

# %%
for pre, fill, node in RenderTree(root):
    print("%s%s" % (pre, node.name))
# Out:
# 87818409
# ├── 10000
# ├── 10005
# ├── 10006
# ├── 10007
# ├── 10008
# ├── 10009
# ├── 10010
# │   └── 10002
# │       └── 10001
# │           └── 10004
# ├── 10012
# ├── 10013
# ├── 10014
# ├── 10016
# ├── 10017
# ├── 10018
# ├── 10019
# ├── 10022
# │   └── 10003
# ├── 10023
# ├── 10024
# ├── 10025
# ├── 10026
# │   ├── 10011
# │   └── 10015
# ├── 10027
# ├── 10028
# ├── 10029
# ├── 10030
# ├── 10031
# ├── 10032
# ├── 10033
# ├── 10034
# ├── 10035
# └── 10036

# %%
conversation = traceConversation(df, root, '10010')
conversation
# Out:
# All child nodes:
# 10002
# 10001
# 10004
#
# 10010
# └── 10002
#     └── 10001
#         └── 10004
#                     id                 timestamp            reply_to  \
# 1            183334937  2022-03-01T21:28:54.000Z           441670370
# 2            441670370  2022-03-01T19:56:23.000Z  984163135715139584
# 4            441670370  2022-03-01T19:47:13.000Z           183334937
# 10  984163135715139584  2022-03-01T08:58:01.000Z            87818409
#
#                                               comment new_id reply_to_id  url  \
# 1   @HohoChan657 @DanielArcher007 @guardian Really...  10001       10002  NaN
# 2   @Ted_Wilson_efg @guardian Sanction AmeriKKKa f...  10002       10010  NaN
# 4   @andalg1 @DanielArcher007 @guardian Cancel all...  10004       10001  NaN
# 10  @guardian Are the Guardian's arts editors seri...  10010    87818409  NaN
#
#    link_title
# 1         NaN
# 2         NaN
# 4         NaN
# 10        NaN

# %%
# count = 0
# previous_scores = []

# for i in conversation.iloc():
#     if count != 0:
#         print(i['comment'], i['sentiment'])
#         print('Bias Score:', confirmationBiasScore(previous_scores, i['sentiment']))
#         print()
        
#     previous_scores.append(i['sentiment'])
    
#     count += 1

# %%
# def confirmationBiasScore(scores, current_score, threshold = 0.5):
#     positive_evidence = 0
#     negative_evidence = 0
    
#     neg_evidence_agree = 0
#     neg_evidence_disagree = 0
#     pos_evidence_agree = 0
#     pos_evidence_disagree = 0
    
#     for i in range(len(scores)):
#         if scores[i] < threshold:
#             negative_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] >= threshold:
#                 neg_evidence_disagree += 1
#             else:
#                 neg_evidence_agree += 1
#         else:
#             positive_evidence += 1
            
#             if i < len(scores) - 1 and scores[i+1] < threshold:
#                 pos_evidence_disagree += 1
#             else:
#                 pos_evidence_agree += 1
    
#     try: H1 = pos_evidence_agree / (pos_evidence_agree + pos_evidence_disagree)
#     except: H1 = 0
        
#     try: H2 = neg_evidence_agree / (neg_evidence_agree + neg_evidence_disagree)
#     except: H2 = 0
            
#     # Assume D1 is positive evidence
#     D1 = positive_evidence / (positive_evidence + negative_evidence)
#     D2 = negative_evidence / (positive_evidence + negative_evidence)
    
#     try:
#         prob_D1_H1 = (D1 * H1) / ((D1 * H1) + (D2 * H1))
#     except:
#         prob_D1_H1 = 0
        
#     try:
#         prob_D1_H2 = (D1 * H2) / ((D1 * H2) + (D2 * H2))
#     except:
#         prob_D1_H2 = 0
    
#     return prob_D1_H1, prob_D1_H2
